# %% [markdown]
# <a href="https://colab.research.google.com/github/fedeprocops/Data-analysis-portfolio/blob/main/notebooks/Sprint9_Time_Series_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sprint 9: Time Series Basics

# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-25bea51f-f6cf-486a-8f79-4ae6642c34c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25bea51f-f6cf-486a-8f79-4ae6642c34c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("netflix_titles_cleaned.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df["date_added"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Utilizziamo set_indext('date') per impostare la colonna date come indice visto che nelle serie temporali, il tempo diventa la dimensione principale dell'analisi. In questo modo è possibile eseguire operazioni specifiche sulle date, come selezioni per periodo, aggregazioni temporali e calcolo di medie mobili.

# %%
df['date_added'].head()
# Out:
# 0    September 25, 2021
# 1    September 24, 2021
# 2    September 24, 2021
# 3    September 24, 2021
# 4    September 24, 2021
# Name: date_added, dtype: object

# %% [markdown]
# Conversione del formato time: con pd.to_datetime

# %%
df['date_added'] = pd.to_datetime(
    df['date_added'],
    errors='coerce'
)

# %% [markdown]
# Estrazione dei componenti temporali

# %%
df['year_added'] = df['date_added'].dt.year

# %%
df['month_added'] = df['date_added'].dt.month

# %%
df['month_name'] = df['date_added'].dt.month_name()

# %%
df['weekday'] = df['date_added'].dt.day_name()

# %%
df['day'] = df['date_added'].dt.day

# %%
df[['date_added', 'year_added', 'month_name', 'weekday']].head()
# Out:
#   date_added  year_added month_name   weekday
# 0 2021-09-25      2021.0  September  Saturday
# 1 2021-09-24      2021.0  September    Friday
# 2 2021-09-24      2021.0  September    Friday
# 3 2021-09-24      2021.0  September    Friday
# 4 2021-09-24      2021.0  September    Friday

# %%
df['year_added'].value_counts().sort_index()
# Out:
# year_added
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      10
# 2014.0      23
# 2015.0      73
# 2016.0     415
# 2017.0    1161
# 2018.0    1624
# 2019.0    1999
# 2020.0    1878
# 2021.0    1498
# Name: count, dtype: int64

# %% [markdown]
# Il numero di film aggiunti al catalogo Netflix cresce costantemente fino al 2019, anno in cui raggiunge il valore massimo. Successivamente si osserva una riduzione nel 2020 e nel 2021. Una possibile spiegazione potrebbe essere un cambiamento nella strategia di contenuti della piattaforma o fattori esterni che hanno influenzato la produzione e la distribuzione cinematografica. Per verificare l'ipotesi di una maggiore preferenza verso le serie TV sarebbero necessari dati sulle visualizzazioni o sulle abitudini degli utenti.

# %% [markdown]
# Convertiamo la colonna date_added e smontiamo i suoi componenti:

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          Unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   cast          8790 non-null   object
#  5   country       8790 non-null   object
#  6   date_added    8702 non-null   datetime64[ns]
#  7   release_year  8790 non-null   int64
#  8   rating        8790 non-null   object
#  9   duration      8790 non-null   object
#  10  listed_in     8790 non-null   object
#  11  description   8790 non-null   object
#  12  year_added    8702 non-null   float64
#  13  month_added   8702 non-null   float64
#  14  month_name    8702 non-null   object
#  15  weekday       8702 non-null   object
#  16  day           8702 non-null   float64
# ...

# %%
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
df['month_name'] = df['date_added'].dt.month_name()
df['weekday'] = df['date_added'].dt.day_name()

# %%
df[
    ['date_added', 'year_added', 'month_added', 'month_name', 'weekday']
].head()
# Out:
#   date_added  year_added  month_added month_name   weekday
# 0 2021-09-25      2021.0          9.0  September  Saturday
# 1 2021-09-24      2021.0          9.0  September    Friday
# 2 2021-09-24      2021.0          9.0  September    Friday
# 3 2021-09-24      2021.0          9.0  September    Friday
# 4 2021-09-24      2021.0          9.0  September    Friday

# %%
df['year_added'].value_counts().sort_index()
# Out:
# year_added
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      10
# 2014.0      23
# 2015.0      73
# 2016.0     415
# 2017.0    1161
# 2018.0    1624
# 2019.0    1999
# 2020.0    1878
# 2021.0    1498
# Name: count, dtype: int64

# %%
df_time = df.set_index('date_added')

# %%
df_time = df_time.sort_index()

# %%
df_time.loc['2019-09']
# Out:
#            show_id     type  \
# date_added
# 2019-09-01   s3542  TV Show
# 2019-09-01   s3543    Movie
# 2019-09-01   s3541  TV Show
# 2019-09-01   s6760    Movie
# 2019-09-01   s8242    Movie
# ...            ...      ...
# 2019-09-28   s6624    Movie
# 2019-09-28   s3481    Movie
# 2019-09-28   s3480    Movie
# 2019-09-30   s3478  TV Show
# 2019-09-30   s3479    Movie
#
#                                                         title  \
# date_added
# 2019-09-01                                             Naruto
# 2019-09-01                                 Olmo & the Seagull
# 2019-09-01                                         Moving Art
# 2019-09-01                                         First Kill
# 2019-09-01                                            The CEO
# ...                                                       ...
# 2019-09-28                                             Domino
# 2019-09-28                                          TUNA GIRL
# ...

# %% [markdown]
# Tutti i titoli di settembre 2019

# %%
df_time = df.set_index('date_added')
df_time = df_time.sort_index()

# %%
df_time.head()
# Out:
#            show_id     type                        title  \
# date_added
# 2008-01-01   s5958    Movie         To and From New York
# 2008-02-04   s6612  TV Show              Dinner for Five
# 2009-05-05   s5957    Movie      Just Another Love Story
# 2009-11-18   s5956    Movie                     Splatter
# 2010-11-01   s7371    Movie  Mad Ron's Prevues from Hell
#
#                         director  \
# date_added
# 2008-01-01  Sorin Dan Mihalcescu
# 2008-02-04               Unknown
# 2009-05-05          Ole Bornedal
# 2009-11-18             Joe Dante
# 2010-11-01            Jim Monaco
#
#                                                          cast        country  \
# date_added
# 2008-01-01  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 2008-02-04                                            Unknown  United States
# 2009-05-05  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# ...

# %%
df_time.index
# Out:
# DatetimeIndex(['2008-01-01', '2008-02-04', '2009-05-05', '2009-11-18',
#                '2010-11-01', '2011-05-17', '2011-09-27', '2011-10-01',
#                '2011-10-01', '2011-10-01',
#                ...
#                       'NaT',        'NaT',        'NaT',        'NaT',
#                       'NaT',        'NaT',        'NaT',        'NaT',
#                       'NaT',        'NaT'],
#               dtype='datetime64[ns]', name='date_added', length=8790, freq=None)

# %%
titles_per_year = df_time.resample('YE').size()
titles_per_year
# Out:
# date_added
# 2008-12-31       2
# 2009-12-31       2
# 2010-12-31       1
# 2011-12-31      13
# 2012-12-31       3
# 2013-12-31      10
# 2014-12-31      23
# 2015-12-31      73
# 2016-12-31     415
# 2017-12-31    1161
# 2018-12-31    1624
# 2019-12-31    1999
# 2020-12-31    1878
# 2021-12-31    1498
# dtype: int64

# %% [markdown]
# Con questi due step abbiamo raggruppato i dati per fine anno e contato quante righe ci sono in ogni periodo. Possiamo fare una lettura più pulita per anni e per mese

# %%
titles_per_year.index = titles_per_year.index.year
titles_per_year
# Out:
# date_added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      10
# 2014      23
# 2015      73
# 2016     415
# 2017    1161
# 2018    1624
# 2019    1999
# 2020    1878
# 2021    1498
# dtype: int64

# %%
titles_per_month = df_time.resample('ME').size()
titles_per_month.head()
# Out:
# date_added
# 2008-01-31    1
# 2008-02-29    1
# 2008-03-31    0
# 2008-04-30    0
# 2008-05-31    0
# dtype: int64

# %%
df_time.resample('YE').size()
# Out:
# date_added
# 2008-12-31       2
# 2009-12-31       2
# 2010-12-31       1
# 2011-12-31      13
# 2012-12-31       3
# 2013-12-31      10
# 2014-12-31      23
# 2015-12-31      73
# 2016-12-31     415
# 2017-12-31    1161
# 2018-12-31    1624
# 2019-12-31    1999
# 2020-12-31    1878
# 2021-12-31    1498
# dtype: int64

# %% [markdown]
# Questo comando raggruppa i dati per ogni fine anno (YE=YEar End) e conta quante righe ci sono per ciascuno.
# Risponde alla domanda: quanti titoli sono stati aggiungi al catalogo ogni anno?

# %%
df_time.resample('ME').size()
# Out:
# date_added
# 2008-01-31      1
# 2008-02-29      1
# 2008-03-31      0
# 2008-04-30      0
# 2008-05-31      0
#              ...
# 2021-05-31    132
# 2021-06-30    207
# 2021-07-31    257
# 2021-08-31    178
# 2021-09-30    183
# Length: 165, dtype: int64

# %% [markdown]
# Quanti titoli sono stati aggiunti al catalogo in ciascun mese di ciascun anno?

# %% [markdown]
# *Rolling Windows and Moving Average*

# %%
titles_per_month = df_time.resample('ME').size()

# %%
titles_per_month.rolling(3).mean()
# Out:
# date_added
# 2008-01-31           NaN
# 2008-02-29           NaN
# 2008-03-31      0.666667
# 2008-04-30      0.333333
# 2008-05-31      0.000000
#                  ...
# 2021-05-31    144.000000
# 2021-06-30    175.666667
# 2021-07-31    198.666667
# 2021-08-31    214.000000
# 2021-09-30    206.000000
# Length: 165, dtype: float64

# %% [markdown]
# Per ogni mese, calcola la media degli ultimi 3 mesi disponibili.

# %%
titles_per_month.rolling(12).mean()
# Out:
# date_added
# 2008-01-31           NaN
# 2008-02-29           NaN
# 2008-03-31           NaN
# 2008-04-30           NaN
# 2008-05-31           NaN
#                  ...
# 2021-05-31    146.833333
# 2021-06-30    151.083333
# 2021-07-31    160.333333
# 2021-08-31    164.416667
# 2021-09-30    165.666667
# Length: 165, dtype: float64

# %% [markdown]
# Qual è il trend medio degli ultimi 12 mesi?
